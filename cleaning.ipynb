# %%
import pandas as pd

# %%
df=pd.read_csv('C:/Users/user/ashish/project_3/api.csv')

# %%
df.head()
# Out:
#      id         name symbol      slug  infinite_supply  circulating_supply  \
# 0     1      Bitcoin    BTC   bitcoin            False        2.001528e+07
# 1  1027     Ethereum    ETH  ethereum             True        1.206910e+08
# 2   825  Tether USDt   USDT    tether             True        1.844360e+11
# 3    52          XRP    XRP       xrp            False        6.140553e+10
# 4  1839          BNB    BNB       bnb            False        1.363565e+08
#
#    total_supply    max_supply                date_added  num_market_pairs  \
# 0  2.001528e+07  2.100000e+07  2010-07-13T00:00:00.000Z             12601
# 1  1.206910e+08           NaN  2015-08-07T00:00:00.000Z             11741
# 2  1.888730e+11           NaN  2015-02-25T00:00:00.000Z            177320
# 3  9.998569e+10  1.000000e+11  2013-08-04T00:00:00.000Z              1823
# 4  1.363565e+08  1.363565e+08  2017-07-25T00:00:00.000Z              3184
#
# ...

# %%
type(df)
# Out:
# pandas.DataFrame

# %%
df.shape
# Out:
# (150, 40)

# %%
df.columns
# Out:
# Index(['id', 'name', 'symbol', 'slug', 'infinite_supply', 'circulating_supply',
#        'total_supply', 'max_supply', 'date_added', 'num_market_pairs',
#        'cmc_rank', 'last_updated', 'tvl_ratio', 'platform',
#        'self_reported_circulating_supply', 'self_reported_market_cap',
#        'minted_market_cap', 'tags', 'quote.USD.price', 'quote.USD.volume_24h',
#        'quote.USD.cex_volume_24h', 'quote.USD.dex_volume_24h',
#        'quote.USD.volume_change_24h', 'quote.USD.percent_change_1h',
#        'quote.USD.percent_change_24h', 'quote.USD.percent_change_7d',
#        'quote.USD.percent_change_30d', 'quote.USD.percent_change_60d',
#        'quote.USD.percent_change_90d', 'quote.USD.market_cap',
#        'quote.USD.market_cap_dominance', 'quote.USD.fully_diluted_market_cap',
#        'quote.USD.tvl', 'quote.USD.last_updated', 'platform.id',
#        'platform.slug', 'platform.name', 'platform.symbol',
#        'platform.token_address', 'Timestamp'],
#       dtype='str')

# %%
for i in df.columns:
    print(df[i].value_counts())
# Out:
# id
# 1        10
# 1027     10
# 825      10
# 52       10
# 1839     10
# 3408     10
# 5426     10
# 1958     10
# 74       10
# 32196    10
# 3957     10
# 2010     10
# 1831     10
# 328      10
# 1975     10
# Name: count, dtype: int64
# name
# Bitcoin         10
# Ethereum        10
# Tether USDt     10
# XRP             10
# BNB             10
# USDC            10
# Solana          10
# TRON            10
# Dogecoin        10
# Hyperliquid     10
# UNUS SED LEO    10
# Cardano         10
# Bitcoin Cash    10
# Monero          10
# Chainlink       10
# Name: count, dtype: int64
# symbol
# BTC     10
# ETH     10
# USDT    10
# XRP     10
# BNB     10
# USDC    10
# SOL     10
# TRX     10
# DOGE    10
# HYPE    10
# LEO     10
# ADA     10
# BCH     10
# XMR     10
# LINK    10
# Name: count, dtype: int64
# slug
# bitcoin         10
# ethereum        10
# tether          10
# xrp             10
# bnb             10
# usd-coin        10
# solana          10
# tron            10
# ...

# %% [markdown]
# ## The data is already cleaned as it doesn't contain null values
